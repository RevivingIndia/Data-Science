# %%
import pandas as pd

df = pd.read_csv('salaries.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                                             NaN
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER                                             NaN
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18         0.00  400184.25  567595.43         567595.43  2011
# 1  155966.02    245131.88  137811.38  538909.28         538909.28  2011
# 2        NaN    106088.18   16452.60        NaN               NaN  2011
# 3   77916.00     56120.71        NaN  332343.61         332343.61  2011
# 4  134401.60      9737.00  182234.59  326373.19         326373.19  2011
#
#           Agency
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# ...

# %%
df.isna()
# Out:
#        Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  TotalPay  \
# 0   False         False     False    False        False     False     False
# 1   False         False      True    False        False     False     False
# 2   False         False     False     True        False     False      True
# 3   False         False     False    False        False      True     False
# 4   False         False      True    False        False     False     False
# 5   False         False     False    False        False     False     False
# 6   False         False     False    False        False     False     False
# 7   False         False     False    False        False     False     False
# 8   False         False     False    False        False     False     False
# 9   False         False     False    False        False     False     False
# 10  False         False     False    False        False     False     False
# ...

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                                             NaN
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER                                             NaN
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18         0.00  400184.25  567595.43         567595.43  2011
# 1  155966.02    245131.88  137811.38  538909.28         538909.28  2011
# 2        NaN    106088.18   16452.60        NaN               NaN  2011
# 3   77916.00     56120.71        NaN  332343.61         332343.61  2011
# 4  134401.60      9737.00  182234.59  326373.19         326373.19  2011
#
#           Agency
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# ...

# %%
df.fillna(method='bfill')
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER                         ASSISTANT DEPUTY CHIEF II
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                                             NaN
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER                                             NaN
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18         0.00  400184.25  567595.43         567595.43  2011
# 1  155966.02    245131.88  137811.38  538909.28         538909.28  2011
# 2        NaN    106088.18   16452.60        NaN               NaN  2011
# 3   77916.00     56120.71        NaN  332343.61         332343.61  2011
# 4  134401.60      9737.00  182234.59  326373.19         326373.19  2011
#
#           Agency
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# ...

# %%
import numpy as np
df.replace({
    'BasePay':[167411.18,155966.02]
},np.NAN)
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                                               NaN
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER                                               NaN
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
df.interpolate(method='linear')
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                                               NaN
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER                                               NaN
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                                             NaN
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER                                             NaN
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18         0.00  400184.25  567595.43         567595.43  2011
# 1  155966.02    245131.88  137811.38  538909.28         538909.28  2011
# 2        NaN    106088.18   16452.60        NaN               NaN  2011
# 3   77916.00     56120.71        NaN  332343.61         332343.61  2011
# 4  134401.60      9737.00  182234.59  326373.19         326373.19  2011
#
#           Agency
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# ...

# %%
df.dropna(inplace='True')
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 11  12    PATRICIA JACKSON                   CAPTAIN III (POLICE DEPARTMENT)
# 12  13   EDWARD HARRINGTON                       EXECUTIVE CONTRACT EMPLOYEE
# 13  14         JOHN MARTIN                                 DEPARTMENT HEAD V
# 14  15      DAVID FRANKLIN                BATTALION CHIEF, (FIRE DEPARTMENT)
# ...
